# %%
# Requires Python 3.7
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113   
# !pip install -U pip wheel setuptools
# !pip install tensorflow==1.15.0 --user
# !pip install tensorflow-gpu==1.15.0 --user
# !pip install stable_baselines[mpi] --user
# !pip install "gym==0.19.0" --user
# !pip install box2d-py --user
# !pip3 install atari-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\itsdr\appdata\roaming\python\python37\site-packages)
# ...

# %%
import gym 
from stable_baselines.common.vec_env import VecFrameStack
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.evaluation import evaluate_policy
from stable_baselines.common.cmd_util import make_atari_env
import os

from stable_baselines import A2C
from stable_baselines import ACER
from stable_baselines import PPO2
from stable_baselines import DQN
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\itsdr\AppData\Roaming\Python\Python37\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
# ...

# %%
env1 = make_atari_env('BreakoutNoFrameskip-v0', num_env=1, seed=0)
env1 = VecFrameStack(env1, n_stack=1)
env4 = make_atari_env('BreakoutNoFrameskip-v0', num_env=4, seed=0)
env4 = VecFrameStack(env4, n_stack=4)
log_path = os.path.join('.\Training_Breakout2', 'Logs')

# %%
# !rm -rf ./Training_Breakout2/Logs/

model_breakout_A2C = A2C("CnnPolicy", env4, verbose=1, tensorboard_log=log_path)
model_breakout_ACER = ACER("CnnPolicy", env4, verbose=1, tensorboard_log=log_path)
model_breakout_PPO2 = PPO2("CnnPolicy", env4, verbose=1, tensorboard_log=log_path)
model_breakout_DQN = DQN("CnnPolicy", env1, verbose=1, tensorboard_log=log_path)

# %%
from tensorboard import notebook
# %load_ext tensorboard
# %reload_ext tensorboard

notebook.list() # View open TensorBoard instances
# Out:
# Known TensorBoard instances:
#   - port 6011: logdir .\Training_MsPacman\Logs\ACER_1 (started 21:52:26 ago; pid 10292)
#   - port 6015: logdir .\Training_Breakout500k\Logs\ACER_1 (started 19:30:55 ago; pid 11032)
#   - port 6008: logdir .\Training\Logs\PPO2_1 (started 23:52:45 ago; pid 1300)
#   - port 6007: logdir .\Training_Breakout\Logs\ACER_1 (started 21:50:19 ago; pid 14256)
#   - port 6006: logdir .\Training_Breakout\Logs\A2C_1 (started 21:50:33 ago; pid 14436)
#   - port 6007: logdir .\Training_Breakout\Logs\ACER_1 (started 21:54:22 ago; pid 16784)
#   - port 6015: logdir .\Training_Breakout500k\Logs\ACER_1 (started 12:11:10 ago; pid 16812)
#   - port 6017: logdir .\Training_Breakout500k\Logs\DQN_1 (started 19:30:54 ago; pid 16912)
#   - port 6010: logdir .\Training_MsPacman\Logs\A2C_1 (started 21:59:04 ago; pid 1816)
#   - port 6014: logdir .\Training_Breakout500k\Logs\A2C_1 (started 19:33:07 ago; pid 19612)
# ...

# %%
# Must manually stop/interupt (i,i) x 3
# Only run this block once! (I commented out to ensure it doesn't run again!)
# training_log_path = os.path.join(log_path, 'A2C_1')
# !tensorboard --port=6010 --logdir={training_log_path}

# training_log_path = os.path.join(log_path, 'ACER_1')
# !tensorboard --port=6011 --logdir={training_log_path}

# training_log_path = os.path.join(log_path, 'PPO2_1')
# !tensorboard --port=6012 --logdir={training_log_path}

# training_log_path = os.path.join(log_path, 'DQN_1')
# !tensorboard --port=6013 --logdir={training_log_path}
# Out:
# ^C
# ^C
# ^C
# ^C

# %%
print("LEARN A2C:")
model_breakout_A2C.learn(total_timesteps=100000)
# Out:
# LEARN A2C:
# ---------------------------------
# | explained_variance | -47.9    |
# | fps                | 44       |
# | nupdates           | 1        |
# | policy_entropy     | 1.39     |
# | total_timesteps    | 20       |
# | value_loss         | 0.00447  |
# ---------------------------------
# ---------------------------------
# | ep_len_mean        | 196      |
# | ep_reward_mean     | 1.6      |
# | explained_variance | -1.79    |
# | fps                | 206      |
# | nupdates           | 100      |
# | policy_entropy     | 1.39     |
# | total_timesteps    | 2000     |
# | value_loss         | 0.00355  |
# ---------------------------------
# ---------------------------------
# | ep_len_mean        | 205      |
# | ep_reward_mean     | 1.89     |
# | explained_variance | -0.467   |
# | fps                | 209      |
# | nupdates           | 200      |
# | policy_entropy     | 1.39     |
# | total_timesteps    | 4000     |
# | value_loss         | 0.00697  |
# ...

# %%
breakout_a2c_path = os.path.join('.\Training_Breakout2', 'Saved Models', 'A2C_model')
model_breakout_A2C.save(breakout_a2c_path)
del model_breakout_A2C

# %%
print("LEARN ACER:")
model_breakout_ACER.learn(total_timesteps=100000)
# Out:
# LEARN ACER:
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.0283   |
# | avg_norm_grads_f    | 0.0283   |
# | avg_norm_k          | 2        |
# | avg_norm_k_dot_g    | 0.0283   |
# | entropy             | 116      |
# | explained_variance  | -0.172   |
# | fps                 | 0        |
# | loss                | -1.17    |
# | loss_bc             | -0       |
# | loss_f              | -0.00472 |
# | loss_policy         | -0.00472 |
# | loss_q              | 5.02e-05 |
# | mean_episode_length | 10       |
# | mean_episode_reward | 0        |
# | norm_grads          | 0.0104   |
# | norm_grads_policy   | 0.00506  |
# | norm_grads_q        | 0.00912  |
# | total_timesteps     | 80       |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.281    |
# | avg_norm_grads_f    | 0.281    |
# | avg_norm_k          | 2        |
# ...

# %%
breakout_acer_path = os.path.join('.\Training_Breakout2', 'Saved Models', 'ACER_model')
model_breakout_ACER.save(breakout_acer_path)
del model_breakout_ACER

# %%
print("LEARN PPO2:")
model_breakout_PPO2.learn(total_timesteps=100000)
# Out:
# LEARN PPO2:
# ---------------------------------------
# | approxkl           | 0.00044097705  |
# | clipfrac           | 0.0            |
# | ep_len_mean        | 150            |
# | ep_reward_mean     | 0.8            |
# | explained_variance | -0.0423        |
# | fps                | 161            |
# | n_updates          | 1              |
# | policy_entropy     | 1.3858423      |
# | policy_loss        | -0.00038170436 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 0              |
# | total_timesteps    | 512            |
# | value_loss         | 0.033146605    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00067540334 |
# | clipfrac           | 0.0           |
# | ep_len_mean        | 143           |
# | ep_reward_mean     | 0.571         |
# | explained_variance | 0.0185        |
# | fps                | 184           |
# | n_updates          | 2             |
# ...

# %%
breakout_ppo2_path = os.path.join('.\Training_Breakout2', 'Saved Models', 'PPO2_model')
model_breakout_PPO2.save(breakout_ppo2_path)
del model_breakout_PPO2

# %%
env.close()
